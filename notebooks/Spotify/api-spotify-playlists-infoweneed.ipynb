# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Coloca tus credenciales aquí
CLIENT_ID = '3f8cc110d1534d4ba1cd6d063cf114e3'
CLIENT_SECRET = '2c63ffda0e7d4247aaa719de974460bf'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
class Eurovision:

    def __init__(self,raw):
        self.raw = raw
        
    def add_data(self):
        #Función para crear el DF con los datos de las canciones
        eurovision_datos= []

        for item in self.raw["tracks"]["items"]:
            track = item["track"]
            artist = item["track"]["artists"]
            
            eurovision_datos.append({
                 
                "artists_name": artist[0]["name"],
                "track_name": track["name"],
                "popularity": track["popularity"], 
                "playlist_followers": self.raw["followers"]["total"],
                "duration": track["duration_ms"]  
            })

        df_eurovision_data = pd.DataFrame(eurovision_datos)
        return df_eurovision_data

# %% [markdown]
# # 2019

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2019

info_raw19 = sp.playlist("https://open.spotify.com/playlist/3ZdQUt8Tmtt7oOU8UM2koe?si=eea27348cf654d21", fields=None, market=None, additional_types='track',)

eurovision_2019 = Eurovision(info_raw19)

eurovision_2019.add_data()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 3
#       1 # DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2019
# ----> 3 info_raw19 = sp.playlist("https://open.spotify.com/playlist/3ZdQUt8Tmtt7oOU8UM2koe?si=eea27348cf654d21", fields=None, market=None, additional_types='track',)
#       5 eurovision_2019 = Eurovision(info_raw19)
#       7 eurovision_2019.add_data()
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:671, in Spotify.playlist(self, playlist_id, fields, market, additional_types)
#     660 """ Gets playlist by id.
#     661
#     662     Parameters:
#    (...)
#     668                              valid types are: track and episode
#     669 """
#     670 plid = self._get_id("playlist", playlist_id)
# --> 671 return self._get(
#     672     f"playlists/{plid}",
#     673     fields=fields,
#     674     market=market,
#     675     additional_types=",".join(additional_types),
#     676 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:327, in Spotify._get(self, url, args, payload, **kwargs)
#     324 if args:
#     325     kwargs.update(args)
# --> 327 return self._internal_call("GET", url, payload, kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:251, in Spotify._internal_call(self, method, url, payload, params)
#     249 if not url.startswith("http"):
#     250     url = self.prefix + url
# --> 251 headers = self._auth_headers()
#     253 if "content_type" in args["params"]:
#     254     headers["Content-Type"] = args["params"]["content_type"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/client.py:242, in Spotify._auth_headers(self)
#     240     return {}
#     241 try:
# --> 242     token = self.auth_manager.get_access_token(as_dict=False)
#     243 except TypeError:
#     244     token = self.auth_manager.get_access_token()
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/oauth2.py:207, in SpotifyClientCredentials.get_access_token(self, as_dict, check_cache)
#     204     if token_info and not self.is_token_expired(token_info):
#     205         return token_info if as_dict else token_info["access_token"]
# --> 207 token_info = self._request_access_token()
#     208 token_info = self._add_custom_values_to_token_info(token_info)
#     209 self.cache_handler.save_token_to_cache(token_info)
#
# File /opt/anaconda3/lib/python3.12/site-packages/spotipy/oauth2.py:226, in SpotifyClientCredentials._request_access_token(self)
#     220 logger.debug(
#     221     "sending POST request to %s with Headers: %s and Body: %r",
#     222     self.OAUTH_TOKEN_URL, headers, payload
#     223 )
#     225 try:
# --> 226     response = self._session.post(
#     227         self.OAUTH_TOKEN_URL,
#     228         data=payload,
#     229         headers=headers,
#     230         verify=True,
#     231         proxies=self.proxies,
#     232         timeout=self.requests_timeout,
#     233     )
#     234     response.raise_for_status()
#     235     token_info = response.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:693, in HTTPSConnection.connect(self)
#     691 try:
#     692     sock: socket.socket | ssl.SSLSocket
# --> 693     self.sock = sock = self._new_conn()
#     694     server_hostname: str = self.host
#     695     tls_in_tls = False
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     194 """Establish a socket connection and set nodelay settings on it.
#     195
#     196 :return: New socket connection.
#     197 """
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#     206     raise NameResolutionError(self.host, self, e) from e
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      71 if source_address:
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#      75 err = None
#
# KeyboardInterrupt:

# %% [markdown]
# # 2021

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2021

info_raw21 = sp.playlist("https://open.spotify.com/playlist/5h0sQpJnLVzgy5iOH1UNcl?si=3a1d926528484506", fields=None, market=None, additional_types='track',)

eurovision_2021 = Eurovision(info_raw21)

eurovision_2021.add_data()
# Out:
#          artists_name                                      track_name  \
# 0            Måneskin                                   ZITTI E BUONI
# 1                Go_A                                            SHUM
# 2       Barbara Pravi                                           Voilà
# 3        Gjon's Tears                                  Tout l'univers
# 4          Daði Freyr                                        10 Years
# 5             Destiny         Je me casse - Eurovision Official Entry
# 6            THE ROOP                                      Discoteque
# 7             Manizha                                   RUSSIAN WOMAN
# 8            Stefania                                      Last Dance
# 9     The Black Mamba                              Love Is On My Side
# 10  Natalia Gordienko                                           Sugar
# 11         Eden Alene                                     Set Me Free
# 12             Efendi                                       Mata Hari
# 13             Senhit                                      Adrenalina
# 14          Montaigne                                    Technicolour
# 15      Fyr Og Flamme                              Øve Os På Hinanden
# 16                TIX                                    Fallen Angel
# 17              Tusse                                          Voices
# 18       James Newman                                          Embers
# 19    Elena Tsagrinou                                       El Diablo
# 20             Albina                                       Tick-Tock
# 21         Lesley Roy                                            Maps
# 22              Roxen                                         Amnesia
# 23         Eden Alene                                     Set Me Free
# 24   Rafał Brzozowski                                        The Ride
# 25       Samanta Tina                   The Moon Is Rising - Original
# 26       Benny Cristo                                           Omaga
# 27        Uku Suviste                                   The lucky one
# 28       Hooverphonic                                 The Wrong Place
# 29           VICTORIA  growing up is getting old - Eurovision Version
# 30   Vasil Garvanliev                                    Here I Stand
# 31      Vincent Bueno                                            Amen
# 32     Jeangu Macrooy                              Birth Of A New Age
# 33         Blas Cantó                                  Voy a quedarme
# 34    Tornike Kipiani                                             You
# 35          Hurricane                                       Loco Loco
# 36  Anxhela Peristeri                                           Karma
# 37  Anxhela Peristeri                                           Karma
# 38            Jendrik                               I Don't Feel Hate
# 39         Ana Soklič                                            Amen
# 40      Blind Channel                                       Dark Side
# 41  Marco Dalla Villa                  Maps - Marco Dalla Villa Remix
# 42         Daði Freyr                        10 Years - Chromeo Remix
# 43           THE ROOP                      Discoteque - Deepend Remix
# 44               Go_A                            SHUM - Dj NANA Remix
# 45             Albina                Tick-Tock - Stefy De Cicco Remix
# 46     Jeangu Macrooy                Birth Of A New Age - Mason Remix
# 47       Hooverphonic      The Wrong Place - Hairglow French Crop Mix
# 48    Elena Tsagrinou            El Diablo - Joytide & Maarlind Remix
# 49       Gjon's Tears                  Tout l'univers - Tiery F Remix
# 50             Senhit                   Adrenalina - Steve Aoki Remix
# 51         Ana Soklič                       Amen (Summer Vibes Remix)
# 52  Scott Elk Artwork                   Movement IV - Dawn + Stardust
#
#     popularity  playlist_followers  duration
# 0           52               32302    192654
# 1            0               32302    172675
# 2           62               32302    176815
# 3            0               32302    183706
# 4            0               32302    166000
# 5           13               32302    178500
# 6           40               32302    180521
# 7           38               32302    176877
# 8           36               32302    180000
# 9           25               32302    175960
# 10          34               32302    178500
# 11          36               32302    179439
# 12          44               32302    160980
# 13          35               32302    179786
# 14          31               32302    169273
# 15          31               32302    186750
# 16          40               32302    173786
# 17          44               32302    184000
# 18           0               32302    175914
# 19          20               32302    181546
# 20          31               32302    180000
# 21          30               32302    172122
# 22          33               32302    174125
# 23           0               32302    174142
# 24          26               32302    180813
# 25          25               32302    180000
# 26          25               32302    179754
# 27          24               32302    182727
# 28          35               32302    176506
# 29          27               32302    188170
# 30          15               32302    180500
# 31          20               32302    175555
# 32          27               32302    173375
# 33          29               32302    182807
# 34          17               32302    183640
# 35           0               32302    175375
# 36           0               32302    180000
# 37           0               32302    179200
# 38           0               32302    176996
# 39          19               32302    184704
# 40           0               32302    177789
# 41          13               32302    179566
# 42           0               32302    163320
# 43          16               32302    153030
# 44           0               32302    152741
# 45          12               32302    161250
# 46           9               32302    217443
# 47          14               32302    208520
# 48          17               32302    171147
# 49           0               32302    191040
# 50          21               32302    190000
# 51           8               32302    268500
# 52           6               32302    216013

# %% [markdown]
# # 2022

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2022

info_raw22 = sp.playlist("https://open.spotify.com/playlist/3EBtzzGyrlDUr1QvXVGz0h?si=DMNkLRIjQE6THtHUYc-oQw", fields=None, market=None, additional_types='track',)

eurovision_2022 = Eurovision(info_raw22)

eurovision_2022.add_data()
# Out:
#                  artists_name  \
# 0                      KALUSH
# 1                   Sam Ryder
# 2                      Chanel
# 3             Cornelia Jakobs
# 4                  Konstrakta
# 5                     Mahmood
# 6                Zdob si Zdub
# 7             Amanda Tenfjord
# 8                        MARO
# 9                  Subwoolfer
# 10                        S10
# 11                     Ochman
# 12                     STEFAN
# 13                 Monika LIU
# 14              Sheldon Riley
# 15             Nadir Rustamli
# 16                Marius Bear
# 17                Andrei Ursu
# 18            Jérémie Makiese
# 19                  Rosa Linn
# 20                 The Rasmus
# 21                We Are Domi
# 22                     Systur
# 23                      Alvan
# 24               Malik Harris
# 25                 Mia Dimšić
# 26                     Andrea
# 27              Ronela Hajati
# 28                 Andromache
# 29                      REDDI
# 30          Michael Ben David
# 31                  Citi Zēni
# 32              Achille Lauro
# 33                      LUM!X
# 34                     Brooke
# 35  Intelligent Music Project
# 36                Emma Muscat
# 37                        LPS
# 38                    Vladana
# 39              Circus Mircus
#
#                                           track_name  popularity  \
# 0                        Stefania (Kalush Orchestra)           0
# 1           SPACE MAN - Eurovision Song Contest Edit          26
# 2               SloMo - Eurovision's Dancebreak Edit           0
# 3                Hold Me Closer - Eurovision Version          35
# 4                                    In corpore sano          37
# 5                                            Brividi          58
# 6   Trenulețul (cu Frații Advahov) - Eurovision 2022          24
# 7                                       Die Together          36
# 8                                   saudade, saudade          46
# 9                            Give That Wolf A Banana          46
# 10                                         De Diepte          47
# 11                                             River          38
# 12                                              Hope          36
# 13                                       Sentimentai           0
# 14                                      Not The Same          37
# 15                                     Fade to black          34
# 16                                       Boys Do Cry          32
# 17                      Llámame - Eurovision Version          29
# 18                                          Miss You          37
# 19                                              SNAP           0
# 20                                           Jezebel          39
# 21                          Lights Off - ESC Version          35
# 22                                  Með hækkandi sól           0
# 23                                            Fulenn          29
# 24                                         Rockstars          46
# 25                                   Guilty Pleasure           0
# 26                                           Circles          26
# 27                                            SEKRET           0
# 28                                               Ela          36
# 29                                          The Show          27
# 30                                               I.M          26
# 31                                    Eat Your Salad          33
# 32                                          STRIPPER          33
# 33                            Halo (feat. PIA MARIA)          49
# 34                                       That's Rich           0
# 35                                         Intention          19
# 36                                    I Am What I Am          35
# 37                                             Disko          31
# 38                                           Breathe          22
# 39                                        Lock Me In          23
#
#     playlist_followers  duration
# 0                10660    179714
# 1                10660    184560
# 2                10660    180000
# 3                10660    180573
# 4                10660    179482
# 5                10660    199146
# 6                10660    180845
# 7                10660    175466
# 8                10660    181226
# 9                10660    171933
# 10               10660    176603
# 11               10660    180201
# 12               10660    183902
# 13               10660    180000
# 14               10660    178325
# 15               10660    177386
# 16               10660    176602
# 17               10660    184500
# 18               10660    173333
# 19               10660    179551
# 20               10660    190863
# 21               10660    179323
# 22               10660    180733
# 23               10660    166255
# 24               10660    179706
# 25               10660    181506
# 26               10660    180000
# 27               10660    181116
# 28               10660    182484
# 29               10660    180000
# 30               10660    163041
# 31               10660    181034
# 32               10660    173013
# 33               10660    159600
# 34               10660    181813
# 35               10660    178500
# 36               10660    182196
# 37               10660    179623
# 38               10660    180674
# 39               10660    157771

# %% [markdown]
# # 2023

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2023


info_raw23 = sp.playlist("https://open.spotify.com/playlist/61fyG82H3Cha91cgKgQT6S?si=o-Xs3DfHRZyRuR8qaY9mxAW", fields=None, market=None, additional_types='track',)

eurovision_2023 = Eurovision(info_raw23)

eurovision_2023.add_data()
# Out:
#         artists_name                                 track_name  popularity  \
# 0            Käärijä                                Cha Cha Cha          59
# 1             Loreen                                     Tattoo          76
# 2         Alessandra                             Queen of Kings          64
# 3             BLANKA                                       Solo          50
# 4     Andrew Lambrou                       Break a Broken Heart          45
# 5             Victor                              What They Say          29
# 6          Noa Kirel                                    Unicorn          47
# 7              Vesna                          My Sister's Crown          45
# 8           La Zarra                                 Évidemment          49
# 9         The Busker                      Dance (Our Own Party)          33
# 10       TuralTuranX                               Tell Me More          28
# 11        Wild Youth  We Are One - Eurovision Song Contest Edit           0
# 12       Remo Forrer                                   Watergun          45
# 13             Let 3                                   Mama ŠČ!          36
# 14       Mia Nicolai                           Burning Daylight          37
# 15        Luke Black                           Samo mi se spava          38
# 16         Joker Out                                 Carpe Diem          44
# 17              TEYA                     Who the Hell Is Edgar?          46
# 18             Diljá                                      POWER          33
# 19               Iru           Echo - Eurovision 2023 - Georgia          33
# 20           Voyager                                    Promise          39
# 21   Albina Kelmendi                                       Duje          30
# 22           Gustaph                             Because Of You          42
# 23          Brunette                               Future Lover          40
# 24      Piqued Jacks                             Like an Animal           0
# 25     Pasha Parfeni                            Soarele si Luna          40
# 26     Sudden Lights                                       Aijā          34
# 27           TVORCHI        Heart of Steel - Eurovision Version          39
# 28             ALIKA                                    Bridges          41
# 29           Mimicat                                 Ai Coração          35
# 30        Mae Muller                             I Wrote A Song           0
# 31     Marco Mengoni                                   Due Vite          54
# 32    Monika Linkyte                                       Stay          34
# 33     Blanca Paloma                                       EAEA          34
# 34  Lord Of The Lost                            Blood & Glitter          41
# 35            Reiley                          Breaking My Heart          34
# 36    Theodor Andrei                         D.G.T (Off And On)          25
# 37         Joker Out               Carpe Diem - English Version           0
#
#     playlist_followers  duration
# 0                21525    175161
# 1                21525    183374
# 2                21525    147979
# 3                21525    154710
# 4                21525    178506
# 5                21525    179672
# 6                21525    170900
# 7                21525    176800
# 8                21525    181000
# 9                21525    169514
# 10               21525    178750
# 11               21525    172500
# 12               21525    172555
# 13               21525    154888
# 14               21525    184000
# 15               21525    173592
# 16               21525    165702
# 17               21525    159417
# 18               21525    183750
# 19               21525    181461
# 20               21525    183510
# 21               21525    182758
# 22               21525    179908
# 23               21525    166019
# 24               21525    179773
# 25               21525    178800
# 26               21525    180782
# 27               21525    158461
# 28               21525    185610
# 29               21525    174123
# 30               21525    165151
# 31               21525    225652
# 32               21525    184285
# 33               21525    179680
# 34               21525    179100
# 35               21525    165179
# 36               21525    179165
# 37               21525    165816

# %% [markdown]
# # 2024

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2024

info_raw24 = sp.playlist("https://open.spotify.com/playlist/2HMW5JNZNh9HLfIHNzY0DP?si=f29ed55294394682", fields=None, market=None, additional_types='track',)

eurovision_2024 = Eurovision(info_raw24)

eurovision_2024.add_data()
# Out:
#                       artists_name  \
# 0                            Joost
# 1                   Angelina Mango
# 2                             Nemo
# 3                          Slimane
# 4                     Baby Lasagna
# 5                Marcus & Martinus
# 6                    alyona alyona
# 7                        Nebulossa
# 8                     Marina Satti
# 9                      Bambie Thug
# 10                      Eden Golan
# 11                           ISAAK
# 12                  Silvester Belt
# 13  Olly Alexander (Years & Years)
# 14                          Kaleen
# 15                    Windows95Man
# 16                        5MIINUST
# 17                          Mustii
# 18                            LUNA
# 19                            TALI
# 20                    Silia Kapsis
# 21                        Ladaniva
# 22                            Aiko
# 23                            Gåte
# 24                       Teya Dora
# 25                          Raiven
# 26                            Dons
# 27                            SABA
# 28                         iolanda
# 29                           Nutsa
# 30                 Electric Fields
# 31                            Besa
# 32                          Fahree
# 33                   Sarah Bonnici
# 34                          Megara
# 35                   Natalia Barbu
# 36                      Hera Björk
#
#                                            track_name  popularity  \
# 0                                            Europapa          64
# 1                                             la noia          58
# 2                                            The Code          61
# 3                                           Mon amour          60
# 4                                    Rim Tim Tagi Dim          58
# 5                                       Unforgettable          54
# 6                                      Teresa & Maria          57
# 7                                               ZORRA          54
# 8                                                ZARI          48
# 9                                       Doomsday Blue          54
# 10                                          Hurricane          50
# 11                                  Always on the run          54
# 12                                            Luktelk           0
# 13                        Dizzy - Performance Version          20
# 14                                       We Will Rave          51
# 15                                          No Rules!          48
# 16  (nendest) narkootikumidest ei tea me (küll) mi...          46
# 17                            BEFORE THE PARTY'S OVER          45
# 18                                          The Tower          44
# 19                       Fighter - Eurovision Version          46
# 20                                               Liar          36
# 21                                               Jako          47
# 22                      Pedestal - Eurovision version          39
# 23                                            Ulveham           0
# 24                                            Ramonda           0
# 25                                           Veronika          41
# 26                                             Hollow          42
# 27                                               SAND          41
# 28                                              Grito          35
# 29                                        Firefighter          26
# 30                            One Milkali (One Blood)          37
# 31                                              TiTAN          35
# 32                                        Özünlə Apar          37
# 33                                               Loop          39
# 34                                              11:11          36
# 35                                      In the Middle          33
# 36                                  Scared of Heights          33
#
#     playlist_followers  duration
# 0                18273    160218
# 1                18273    189124
# 2                18273    180141
# 3                18273    180908
# 4                18273    179062
# 5                18273    168845
# 6                18273    179473
# 7                18273    183577
# 8                18273    180979
# 9                18273    183741
# 10               18273    178965
# 11               18273    209562
# 12               18273    161142
# 13               18273    180504
# 14               18273    185066
# 15               18273    175896
# 16               18273    167125
# 17               18273    179923
# 18               18273    180333
# 19               18273    179738
# 20               18273    178812
# 21               18273    145432
# 22               18273    177368
# 23               18273    182346
# 24               18273    174352
# 25               18273    166222
# 26               18273    171817
# 27               18273    180959
# 28               18273    176447
# 29               18273    183913
# 30               18273    176883
# 31               18273    176707
# 32               18273    182090
# 33               18273    179727
# 34               18273    180087
# 35               18273    178853
# 36               18273    183657

# %%
# Convertimos a CSV los DataFrame

eurovision_2019.add_data().to_csv("../files/spotify_sql/eurovision19_sql_data.csv")
eurovision_2021.add_data().to_csv("../files/spotify_sql/eurovision21_sql_data.csv")
eurovision_2022.add_data().to_csv("../files/spotify_sql/eurovision22_sql_data.csv")
eurovision_2023.add_data().to_csv("../files/spotify_sql/eurovision23_sql_data.csv")
eurovision_2024.add_data().to_csv("../files/spotify_sql/eurovision24_sql_data.csv")
