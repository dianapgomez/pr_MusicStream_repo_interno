# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Coloca tus credenciales aquí
CLIENT_ID = '3f8cc110d1534d4ba1cd6d063cf114e3'
CLIENT_SECRET = '2c63ffda0e7d4247aaa719de974460bf'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
class Eurovision:

    def __init__(self,raw):
        self.raw = raw
        
    def add_data(self):
        #Función para crear el DF con los datos de las canciones
        eurovision_datos= []

        for item in self.raw["tracks"]["items"]:
            track = item["track"]
            artist = item["track"]["artists"]
            
            eurovision_datos.append({
                 
                "artists_name": artist[0]["name"],
                "track_name": track["name"],
                "popularity": track["popularity"],
                "duration": track["duration_ms"]  
            })

        df_eurovision_data = pd.DataFrame(eurovision_datos)
        return df_eurovision_data

# %% [markdown]
# # 2019

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2019

info_raw19 = sp.playlist("https://open.spotify.com/playlist/3ZdQUt8Tmtt7oOU8UM2koe?si=eea27348cf654d21", fields=None, market=None, additional_types='track',)

eurovision_2019 = Eurovision(info_raw19)

eurovision_2019.add_data()
# Out:
#           artists_name                                         track_name  \
# 0              Chingiz                                 Truth - Radio Edit
# 1         John Lundvik                                  Too Late For Love
# 2   Kate Miller-Heidke                                       Zero Gravity
# 3              Michela                                          Chameleon
# 4              Mahmood                                              Soldi
# 5      Duncan Laurence                                             Arcade
# 6          Lake Malawi                                 Friend of a Friend
# 7               Hatari                                   Hatrið mun sigra
# 8       Katerine Duska                                        Better Love
# 9        Bilal Hassani                                                Roi
# 10      Sergey Lazarev                                             SCREAM
# 11          Luca Hänni                                         She Got Me
# 12                ZENA                                            Like It
# 13               Tamta                                             Replay
# 14             S!sters                                             Sister
# 15        Michael Rice                                     Bigger Than Us
# 16             Leonora                                    Love Is Forever
# 17          zalagasper                       Sebi - Dare To Dream Version
# 18              Serhat                                       Say Na Na Na
# 19              KEiiNO                                  Spirit in the Sky
# 20               Tulia                            Fire Of Love (Pali Się)
# 21      Sarah McTernan                                                 22
# 22               Eliot                                            Wake Up
# 23     Tamara Todevska                                              Proud
# 24              Darude                                          Look Away
# 25              PAENDA                                             Limits
# 26        Victor Crone                                              Storm
# 27               Srbuk                                        Walking Out
# 28             Jurijus                                 Run With the Lions
# 29         Kobi Marimi                                               Home
# 30          Pápai Joci                           Az Én Apám - ESC Version
# 31         Ester Peony                                        On a Sunday
# 32               D-mol                                             Heaven
# 33       Anna Odobescu                                               Stay
# 34            Carousel                                         That Night
# 35       Jonida Maliqi           Ktheju Tokës - Eurovision 2019 / Albania
# 36      Nevena Bozovic                                              Kruna
# 37       Roko Blažević                                          The Dream
# 38          Miki Núñez  La Venda - Eurovision Song Contest / Tel Aviv ...
# 39        CONAN OSIRIS                                         TELEMOVEIS
# 40        Oto Nemsadze                                      Keep On Going
# 41               MARUV                                         Siren Song
#
#     popularity  duration
# 0            0    209411
# 1            0    178133
# 2           34    177443
# 3            0    179698
# 4            0    195476
# 5           70    183624
# 6           31    172641
# 7            0    178920
# 8           26    181360
# 9           18    177250
# 10           0    178643
# 11           0    180816
# 12           0    181381
# 13          36    173812
# 14          19    180000
# 15           0    178098
# 16          28    181013
# 17          22    180013
# 18           0    178930
# 19          42    185157
# 20          22    165846
# 21          20    173214
# 22           0    179400
# 23          28    180000
# 24          22    179613
# 25          12    204714
# 26          31    185625
# 27           0    176903
# 28          18    180806
# 29           0    178237
# 30           0    183750
# 31           0    184933
# 32          12    174782
# 33          16    180517
# 34          21    181523
# 35           0    185192
# 36           0    187125
# 37           0    180074
# 38          26    179558
# 39          25    185688
# 40          14    184878
# 41          36    171130

# %% [markdown]
# # 2021

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2021

info_raw21 = sp.playlist("https://open.spotify.com/playlist/5h0sQpJnLVzgy5iOH1UNcl?si=3a1d926528484506", fields=None, market=None, additional_types='track',)

eurovision_2021 = Eurovision(info_raw21)

eurovision_2021.add_data()
# Out:
#          artists_name                                      track_name  \
# 0            Måneskin                                   ZITTI E BUONI
# 1                Go_A                                            SHUM
# 2       Barbara Pravi                                           Voilà
# 3        Gjon's Tears                                  Tout l'univers
# 4          Daði Freyr                                        10 Years
# 5             Destiny         Je me casse - Eurovision Official Entry
# 6            THE ROOP                                      Discoteque
# 7             Manizha                                   RUSSIAN WOMAN
# 8            Stefania                                      Last Dance
# 9     The Black Mamba                              Love Is On My Side
# 10  Natalia Gordienko                                           Sugar
# 11         Eden Alene                                     Set Me Free
# 12             Efendi                                       Mata Hari
# 13             Senhit                                      Adrenalina
# 14          Montaigne                                    Technicolour
# 15      Fyr Og Flamme                              Øve Os På Hinanden
# 16                TIX                                    Fallen Angel
# 17              Tusse                                          Voices
# 18       James Newman                                          Embers
# 19    Elena Tsagrinou                                       El Diablo
# 20             Albina                                       Tick-Tock
# 21         Lesley Roy                                            Maps
# 22              Roxen                                         Amnesia
# 23         Eden Alene                                     Set Me Free
# 24   Rafał Brzozowski                                        The Ride
# 25       Samanta Tina                   The Moon Is Rising - Original
# 26       Benny Cristo                                           Omaga
# 27        Uku Suviste                                   The lucky one
# 28       Hooverphonic                                 The Wrong Place
# 29           VICTORIA  growing up is getting old - Eurovision Version
# 30   Vasil Garvanliev                                    Here I Stand
# 31      Vincent Bueno                                            Amen
# 32     Jeangu Macrooy                              Birth Of A New Age
# 33         Blas Cantó                                  Voy a quedarme
# 34    Tornike Kipiani                                             You
# 35          Hurricane                                       Loco Loco
# 36  Anxhela Peristeri                                           Karma
# 37  Anxhela Peristeri                                           Karma
# 38            Jendrik                               I Don't Feel Hate
# 39         Ana Soklič                                            Amen
# 40      Blind Channel                                       Dark Side
# 41  Marco Dalla Villa                  Maps - Marco Dalla Villa Remix
# 42         Daði Freyr                        10 Years - Chromeo Remix
# 43           THE ROOP                      Discoteque - Deepend Remix
# 44               Go_A                            SHUM - Dj NANA Remix
# 45             Albina                Tick-Tock - Stefy De Cicco Remix
# 46     Jeangu Macrooy                Birth Of A New Age - Mason Remix
# 47       Hooverphonic      The Wrong Place - Hairglow French Crop Mix
# 48    Elena Tsagrinou            El Diablo - Joytide & Maarlind Remix
# 49       Gjon's Tears                  Tout l'univers - Tiery F Remix
# 50             Senhit                   Adrenalina - Steve Aoki Remix
# 51         Ana Soklič                       Amen (Summer Vibes Remix)
# 52  Scott Elk Artwork                   Movement IV - Dawn + Stardust
#
#     popularity  duration
# 0           52    192654
# 1            0    172675
# 2           62    176815
# 3            0    183706
# 4            0    166000
# 5           13    178500
# 6           40    180521
# 7           38    176877
# 8           36    180000
# 9           25    175960
# 10          34    178500
# 11          36    179439
# 12          44    160980
# 13          35    179786
# 14          31    169273
# 15          31    186750
# 16          40    173786
# 17          44    184000
# 18           0    175914
# 19          20    181546
# 20          31    180000
# 21          30    172122
# 22          33    174125
# 23           0    174142
# 24          26    180813
# 25          25    180000
# 26          25    179754
# 27          24    182727
# 28          35    176506
# 29          27    188170
# 30          15    180500
# 31          20    175555
# 32          27    173375
# 33          29    182807
# 34          17    183640
# 35           0    175375
# 36           0    180000
# 37           0    179200
# 38           0    176996
# 39          19    184704
# 40           0    177789
# 41          13    179566
# 42           0    163320
# 43          16    153030
# 44           0    152741
# 45          12    161250
# 46           9    217443
# 47          14    208520
# 48          17    171147
# 49           0    191040
# 50          21    190000
# 51           8    268500
# 52           6    216013

# %% [markdown]
# # 2022

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2022

info_raw22 = sp.playlist("https://open.spotify.com/playlist/3EBtzzGyrlDUr1QvXVGz0h?si=DMNkLRIjQE6THtHUYc-oQw", fields=None, market=None, additional_types='track',)

eurovision_2022 = Eurovision(info_raw22)

eurovision_2022.add_data()
# Out:
#                  artists_name  \
# 0                      KALUSH
# 1                   Sam Ryder
# 2                      Chanel
# 3             Cornelia Jakobs
# 4                  Konstrakta
# 5                     Mahmood
# 6                Zdob si Zdub
# 7             Amanda Tenfjord
# 8                        MARO
# 9                  Subwoolfer
# 10                        S10
# 11                     Ochman
# 12                     STEFAN
# 13                 Monika LIU
# 14              Sheldon Riley
# 15             Nadir Rustamli
# 16                Marius Bear
# 17                Andrei Ursu
# 18            Jérémie Makiese
# 19                  Rosa Linn
# 20                 The Rasmus
# 21                We Are Domi
# 22                     Systur
# 23                      Alvan
# 24               Malik Harris
# 25                 Mia Dimšić
# 26                     Andrea
# 27              Ronela Hajati
# 28                 Andromache
# 29                      REDDI
# 30          Michael Ben David
# 31                  Citi Zēni
# 32              Achille Lauro
# 33                      LUM!X
# 34                     Brooke
# 35  Intelligent Music Project
# 36                Emma Muscat
# 37                        LPS
# 38                    Vladana
# 39              Circus Mircus
#
#                                           track_name  popularity  duration
# 0                        Stefania (Kalush Orchestra)           0    179714
# 1           SPACE MAN - Eurovision Song Contest Edit          26    184560
# 2               SloMo - Eurovision's Dancebreak Edit           0    180000
# 3                Hold Me Closer - Eurovision Version          35    180573
# 4                                    In corpore sano          37    179482
# 5                                            Brividi          58    199146
# 6   Trenulețul (cu Frații Advahov) - Eurovision 2022          24    180845
# 7                                       Die Together          36    175466
# 8                                   saudade, saudade          46    181226
# 9                            Give That Wolf A Banana          46    171933
# 10                                         De Diepte          47    176603
# 11                                             River          38    180201
# 12                                              Hope          36    183902
# 13                                       Sentimentai           0    180000
# 14                                      Not The Same          37    178325
# 15                                     Fade to black          34    177386
# 16                                       Boys Do Cry          32    176602
# 17                      Llámame - Eurovision Version          29    184500
# 18                                          Miss You          37    173333
# 19                                              SNAP           0    179551
# 20                                           Jezebel          39    190863
# 21                          Lights Off - ESC Version          35    179323
# 22                                  Með hækkandi sól           0    180733
# 23                                            Fulenn          29    166255
# 24                                         Rockstars          46    179706
# 25                                   Guilty Pleasure           0    181506
# 26                                           Circles          26    180000
# 27                                            SEKRET           0    181116
# 28                                               Ela          36    182484
# 29                                          The Show          27    180000
# 30                                               I.M          26    163041
# 31                                    Eat Your Salad          33    181034
# 32                                          STRIPPER          33    173013
# 33                            Halo (feat. PIA MARIA)          49    159600
# 34                                       That's Rich           0    181813
# 35                                         Intention          19    178500
# 36                                    I Am What I Am          35    182196
# 37                                             Disko          31    179623
# 38                                           Breathe          22    180674
# 39                                        Lock Me In          23    157771

# %% [markdown]
# # 2023

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2023


info_raw23 = sp.playlist("https://open.spotify.com/playlist/61fyG82H3Cha91cgKgQT6S?si=o-Xs3DfHRZyRuR8qaY9mxAW", fields=None, market=None, additional_types='track',)

eurovision_2023 = Eurovision(info_raw23)

eurovision_2023.add_data()
# Out:
#         artists_name                                 track_name  popularity  \
# 0            Käärijä                                Cha Cha Cha          59
# 1             Loreen                                     Tattoo          76
# 2         Alessandra                             Queen of Kings          64
# 3             BLANKA                                       Solo          50
# 4     Andrew Lambrou                       Break a Broken Heart          45
# 5             Victor                              What They Say          29
# 6          Noa Kirel                                    Unicorn          47
# 7              Vesna                          My Sister's Crown          45
# 8           La Zarra                                 Évidemment          49
# 9         The Busker                      Dance (Our Own Party)          33
# 10       TuralTuranX                               Tell Me More          28
# 11        Wild Youth  We Are One - Eurovision Song Contest Edit           0
# 12       Remo Forrer                                   Watergun          45
# 13             Let 3                                   Mama ŠČ!          36
# 14       Mia Nicolai                           Burning Daylight          37
# 15        Luke Black                           Samo mi se spava          38
# 16         Joker Out                                 Carpe Diem          44
# 17              TEYA                     Who the Hell Is Edgar?          46
# 18             Diljá                                      POWER          33
# 19               Iru           Echo - Eurovision 2023 - Georgia          33
# 20           Voyager                                    Promise          39
# 21   Albina Kelmendi                                       Duje          30
# 22           Gustaph                             Because Of You          42
# 23          Brunette                               Future Lover          40
# 24      Piqued Jacks                             Like an Animal           0
# 25     Pasha Parfeni                            Soarele si Luna          40
# 26     Sudden Lights                                       Aijā          34
# 27           TVORCHI        Heart of Steel - Eurovision Version          39
# 28             ALIKA                                    Bridges          41
# 29           Mimicat                                 Ai Coração          35
# 30        Mae Muller                             I Wrote A Song           0
# 31     Marco Mengoni                                   Due Vite          54
# 32    Monika Linkyte                                       Stay          34
# 33     Blanca Paloma                                       EAEA          34
# 34  Lord Of The Lost                            Blood & Glitter          41
# 35            Reiley                          Breaking My Heart          34
# 36    Theodor Andrei                         D.G.T (Off And On)          25
# 37         Joker Out               Carpe Diem - English Version           0
#
#     duration
# 0     175161
# 1     183374
# 2     147979
# 3     154710
# 4     178506
# 5     179672
# 6     170900
# 7     176800
# 8     181000
# 9     169514
# 10    178750
# 11    172500
# 12    172555
# 13    154888
# 14    184000
# 15    173592
# 16    165702
# 17    159417
# 18    183750
# 19    181461
# 20    183510
# 21    182758
# 22    179908
# 23    166019
# 24    179773
# 25    178800
# 26    180782
# 27    158461
# 28    185610
# 29    174123
# 30    165151
# 31    225652
# 32    184285
# 33    179680
# 34    179100
# 35    165179
# 36    179165
# 37    165816

# %% [markdown]
# # 2024

# %%
# DataFrame con los artistas, canciones y parámetros establecidos de la lista de reporducción de Eurovisión 2024

info_raw24 = sp.playlist("https://open.spotify.com/playlist/2HMW5JNZNh9HLfIHNzY0DP?si=f29ed55294394682", fields=None, market=None, additional_types='track',)

eurovision_2024 = Eurovision(info_raw24)

eurovision_2024.add_data()
# Out:
#                       artists_name  \
# 0                            Joost
# 1                   Angelina Mango
# 2                             Nemo
# 3                          Slimane
# 4                     Baby Lasagna
# 5                Marcus & Martinus
# 6                    alyona alyona
# 7                        Nebulossa
# 8                     Marina Satti
# 9                      Bambie Thug
# 10                      Eden Golan
# 11                           ISAAK
# 12                  Silvester Belt
# 13  Olly Alexander (Years & Years)
# 14                          Kaleen
# 15                    Windows95Man
# 16                        5MIINUST
# 17                          Mustii
# 18                            LUNA
# 19                            TALI
# 20                    Silia Kapsis
# 21                        Ladaniva
# 22                            Aiko
# 23                            Gåte
# 24                       Teya Dora
# 25                          Raiven
# 26                            Dons
# 27                            SABA
# 28                         iolanda
# 29                           Nutsa
# 30                 Electric Fields
# 31                            Besa
# 32                          Fahree
# 33                   Sarah Bonnici
# 34                          Megara
# 35                   Natalia Barbu
# 36                      Hera Björk
#
#                                            track_name  popularity  duration
# 0                                            Europapa          64    160218
# 1                                             la noia          58    189124
# 2                                            The Code          61    180141
# 3                                           Mon amour          60    180908
# 4                                    Rim Tim Tagi Dim          58    179062
# 5                                       Unforgettable          54    168845
# 6                                      Teresa & Maria          57    179473
# 7                                               ZORRA          54    183577
# 8                                                ZARI          48    180979
# 9                                       Doomsday Blue          54    183741
# 10                                          Hurricane          50    178965
# 11                                  Always on the run          54    209562
# 12                                            Luktelk           0    161142
# 13                        Dizzy - Performance Version          20    180504
# 14                                       We Will Rave          51    185066
# 15                                          No Rules!          48    175896
# 16  (nendest) narkootikumidest ei tea me (küll) mi...          46    167125
# 17                            BEFORE THE PARTY'S OVER          45    179923
# 18                                          The Tower          44    180333
# 19                       Fighter - Eurovision Version          46    179738
# 20                                               Liar          36    178812
# 21                                               Jako          47    145432
# 22                      Pedestal - Eurovision version          39    177368
# 23                                            Ulveham           0    182346
# 24                                            Ramonda           0    174352
# 25                                           Veronika          41    166222
# 26                                             Hollow          42    171817
# 27                                               SAND          41    180959
# 28                                              Grito          35    176447
# 29                                        Firefighter          26    183913
# 30                            One Milkali (One Blood)          37    176883
# 31                                              TiTAN          35    176707
# 32                                        Özünlə Apar          37    182090
# 33                                               Loop          39    179727
# 34                                              11:11          36    180087
# 35                                      In the Middle          33    178853
# 36                                  Scared of Heights          33    183657

# %%
# Convertimos a CSV los DataFrame

eurovision_2019.add_data().to_csv("../../files/spotify_sql/eurovision2019.csv")
eurovision_2021.add_data().to_csv("../../files/spotify_sql/eurovision2021.csv")
eurovision_2022.add_data().to_csv("../../files/spotify_sql/eurovision2022.csv")
eurovision_2023.add_data().to_csv("../../files/spotify_sql/eurovision2023.csv")
eurovision_2024.add_data().to_csv("../../files/spotify_sql/eurovision2024.csv")
