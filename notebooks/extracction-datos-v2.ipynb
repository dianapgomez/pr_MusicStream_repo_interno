# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
# Coloca tus credenciales aquí
CLIENT_ID = 'inserir aqui'
CLIENT_SECRET = 'inserir aqui'

# Autenticación
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
#sp.search(q = "genre:rock year:2020", limit=10, offset=200, type='track', market=None)

# %%
playlist2023 = sp.playlist('https://open.spotify.com/playlist/61fyG82H3Cha91cgKgQT6S?si=o-Xs3DfHRZyRuR8qaY9mxA', fields=None,market=None, additional_types= 'track')

playlist2023
#print(playlist2023.keys())
#print(playlist2023['tracks'].keys())
#items=listadentrodict
#print(playlist2023['tracks']['items'].keys())
# Out:
# {'collaborative': False,
#  'description': '',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/61fyG82H3Cha91cgKgQT6S'},
#  'followers': {'href': None, 'total': 21126},
#  'href': 'https://api.spotify.com/v1/playlists/61fyG82H3Cha91cgKgQT6S?additional_types=t',
#  'id': '61fyG82H3Cha91cgKgQT6S',
#  'images': [{'height': None,
#    'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84244a8fcce8c347bfa4931411',
#    'width': None}],
#  'name': 'Eurovision 2023',
#  'owner': {'display_name': '☆ Vasileia ☆',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/om756ovdo6zociz0qd9k4fwzo'},
#   'href': 'https://api.spotify.com/v1/users/om756ovdo6zociz0qd9k4fwzo',
#   'id': 'om756ovdo6zociz0qd9k4fwzo',
#   'type': 'user',
#   'uri': 'spotify:user:om756ovdo6zociz0qd9k4fwzo'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'AAAAMAPm2pgSa44chdHDMTBDecDEAYBW',
# ...

# %%
pl2023 = [] 

for idx, item in enumerate(playlist2023['tracks']['items']):

   track = item['track']
   pl2023.append([idx, track['artists'][0]['name'], track['artists'][0]['id'], " - ",track['name'], track['popularity'], track['id']])

print(pl2023)
# Out:
# [[0, 'Käärijä', '6LkMGN0t3HDNL8hIvma70r', ' - ', 'Cha Cha Cha', 60, '5RX8T3EoTuXcybAxe6oPAw'], [1, 'Loreen', '49aaHxvAJ0tCh0F15OnwIl', ' - ', 'Tattoo', 78, '1DmW5Ep6ywYwxc2HMT5BG6'], [2, 'Alessandra', '35HMF6Y8dSzNfeJs3X65fw', ' - ', 'Queen of Kings', 65, '14LdhxElpZS0rKVV4nxtdA'], [3, 'BLANKA', '0ML3y0iBY1nq7HWAWP0EFm', ' - ', 'Solo', 52, '3xxjYOFR1y7By2wNDS51XV'], [4, 'Andrew Lambrou', '2LJg6YXPzGpih3QOUmyruJ', ' - ', 'Break a Broken Heart', 46, '5dRAJ9UsR0qyMMKnonWewz'], [5, 'Victor', '3w03DTyLLXIUFyuKgOEJOQ', ' - ', 'What They Say', 30, '7DYkoGwnTbEMGiNuoiB1gs'], [6, 'Noa Kirel', '1wak0ZG1LUrZPYx8RDTQoD', ' - ', 'Unicorn', 48, '6dUregFbvUNqHP5nphqesK'], [7, 'Vesna', '44kmUe319y8RNgOU2deqX6', ' - ', "My Sister's Crown", 47, '59md7R7fW5LjSbZITzzn3n'], [8, 'La Zarra', '0NkmvuSD5Pm8zucjwIpChS', ' - ', 'Évidemment', 50, '18ZX6YaDSOopXPRvfIh8DM'], [9, 'The Busker', '3cwZMxOmqueXfvdmDKN1BR', ' - ', 'Dance (Our Own Party)', 34, '3natKRDYwMSPsLO9nX8y02'], [10, 'TuralTuranX', '4rsNfjzhAhcU
# ...

# %%
pd.DataFrame(pl2023)
# Out:
#      0                 1                       2    3  \
# 0    0           Käärijä  6LkMGN0t3HDNL8hIvma70r   -
# 1    1            Loreen  49aaHxvAJ0tCh0F15OnwIl   -
# 2    2        Alessandra  35HMF6Y8dSzNfeJs3X65fw   -
# 3    3            BLANKA  0ML3y0iBY1nq7HWAWP0EFm   -
# 4    4    Andrew Lambrou  2LJg6YXPzGpih3QOUmyruJ   -
# 5    5            Victor  3w03DTyLLXIUFyuKgOEJOQ   -
# 6    6         Noa Kirel  1wak0ZG1LUrZPYx8RDTQoD   -
# 7    7             Vesna  44kmUe319y8RNgOU2deqX6   -
# 8    8          La Zarra  0NkmvuSD5Pm8zucjwIpChS   -
# 9    9        The Busker  3cwZMxOmqueXfvdmDKN1BR   -
# 10  10       TuralTuranX  4rsNfjzhAhcUx94ERGFvgA   -
# 11  11        Wild Youth  4wZxKygv7GA7oGYzk6bpid   -
# 12  12       Remo Forrer  7LtDT7MR8nsSZxTxcp1glk   -
# 13  13             Let 3  4gs82a9ZgG2faut653OMRD   -
# 14  14       Mia Nicolai  5oSkgLWQpt5bk4B7JeAzKJ   -
# 15  15        Luke Black  3sPiEqLcANa5kAp5RnEHNq   -
# 16  16         Joker Out  0ZNfJyThuy6vLnPEpPaJdf   -
# ...
