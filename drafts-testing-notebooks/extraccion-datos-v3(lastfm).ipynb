# %%
import requests

# %%
import pandas as pd

# %%
import json

# %%
MY_API_KEY = "d32caae8580221bc7c36700494b0b248"
share_secret = "c6c83b7b9898026e4e9436dc4d3aaf09"

# %%
url_api = "http://www.last.fm/api/auth/?api_key={MY_API_KEY}"

# %%
requests.get(url_api)
# Out:
# <Response [200]>

# %%
url_api2 = "http://www.last.fm/api/auth/?api_key={MY_API_KEY}&token={share_secret}"

# %%
requests.get(url_api2)
# Out:
# <Response [200]>

# %%
#API top tracks de artistas

top_tracks = requests.get(f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist=cher&api_key={MY_API_KEY}&format=json")

# %%
datos_top_tracks = top_tracks.json()

# %%
datos_top_tracks.keys()
# Out:
# dict_keys(['toptracks'])

# %%
datos_top_tracks
# Out:
# {'toptracks': {'track': [{'name': 'Believe',
#     'playcount': '5508861',
#     'listeners': '915878',
#     'mbid': '32ca187e-ee25-4f18-b7d0-3b6713f24635',
#     'url': 'https://www.last.fm/music/Cher/_/Believe',
#     'streamable': '0',
#     'artist': {'name': 'Cher',
#      'mbid': 'bfcc6d75-a6a5-4bc6-8282-47aec8531818',
#      'url': 'https://www.last.fm/music/Cher'},
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#       'size': 'extralarge'}],
#     '@attr': {'rank': '1'}},
#    {'name': 'If I Could Turn Back Time',
# ...

# %%
import pandas as pd
import requests

MY_API_KEY = "d32caae8580221bc7c36700494b0b248"

def obtener_datos_top_tracks(artista):
    """Obtiene los 3 top tracks de un artista desde Lastfm."""
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={artista}&api_key={MY_API_KEY}&format=json"
    response = requests.get(url)

    if response.status_code == 200:
        datos = response.json()
        if "toptracks" in datos and "track" in datos["toptracks"]:
            return [{"Artista": artista, "Track": track["name"]} for track in datos["toptracks"]["track"][:5]]
    return []

# Lista de artistas
artistas = ["Efendi", "Aksel", "Diodato"]

# Obtener los top 5 tracks de cada artista y crear lista de diccionarios
lista_tracks = []
for artista in artistas:
    lista_tracks.extend(obtener_datos_top_tracks(artista))

# Convertir la lista de diccionarios en un DataFrame
df = pd.DataFrame(lista_tracks)

# Mostrar el DataFrame
print(df)
# Out:
#     Artista                                              Track
# 0    Efendi                                          Mata Hari
# 1    Efendi                                          Cleopatra
# 2    Efendi                           Mata Hari - slow version
# 3    Efendi  Mata Hari - Eurovision 2021 - Azerbaijan / Kar...
# 4    Efendi  Cleopatra - Eurovision 2020 / Azerbaijan / Kar...
# 5     Aksel                                       Looking Back
# 6     Aksel                                               Hurt
# 7     Aksel                                   Ingenting å tape
# 8     Aksel                                     Sarhoş Saatler
# 9     Aksel                                       Keyfin Bilir
# 10  Diodato                                         Fai rumore
# 11  Diodato                                           Ti muovi
# 12  Diodato                              Che vita meravigliosa
# 13  Diodato                            Fino a farci scomparire
# ...

# %%
#API top albumes de artistas

top_albums = requests.get("http://ws.audioscrobbler.com/2.0/?method=artist.gettopalbums&artist=cher&api_key=d32caae8580221bc7c36700494b0b248&format=json")

# %%
import requests
import pandas as pd

MY_API_KEY = "d32caae8580221bc7c36700494b0b248"

# Diccionario con los top 5 artistas por año
top_artistas_por_año = {
    2020: ["Will Ferrell", "Little Big", "Diodato", "BEN & TAN", "The Mamas"],
    2021: ["Barbara Pravi", "Mäneskin", "Efendi", "Tusse", "THE ROOP"],
    2022: ["Mahmood", "LUM!X", "S10", "MARO", "Subwoolfer"],
    2023: ["Loreen", "Alessandra", "Käärijä", "Marco Mengoni", "BLANKA"],
    2024: ["Joost", "Nemo", "Slimane", "Angelina Mango", "Baby Lasagna"],
}

def obtener_datos_top_tracks(artista, año):
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={artista}&api_key={MY_API_KEY}&format=json"
    response = requests.get(url)

    if response.status_code == 200:
        datos = response.json()
        if "toptracks" in datos and "track" in datos["toptracks"]:
            return [{"Año": año, "Artista": artista, "Track": track["name"]} for track in datos["toptracks"]["track"][:3]]
    return []

# Lista para almacenar los datos
lista_tracks = []

# Recorrer los años y artistas
for año, artistas in top_artistas_por_año.items():
    for artista in artistas:
        lista_tracks.extend(obtener_datos_top_tracks(artista, año))

# Convertir la lista de diccionarios en un DataFrame
df = pd.DataFrame(lista_tracks)

df.to_csv("top_tracks.csv")

# Mostrar el DataFrame
print(df)
# Out:
#      Año         Artista                                              Track
# 0   2020    Will Ferrell                              Husavik (My Hometown)
# 1   2020    Will Ferrell                                     Jaja Ding Dong
# 2   2020    Will Ferrell                      Double Trouble - Film Version
# 3   2020      Little Big                                            Skibidi
# 4   2020      Little Big                                                Uno
# ..   ...             ...                                                ...
# 70  2024  Angelina Mango                                 Ci pensiamo domani
# 71  2024  Angelina Mango                                          melodrama
# 72  2024    Baby Lasagna                                   Rim Tim Tagi Dim
# 73  2024    Baby Lasagna                                             IG BOY
# 74  2024    Baby Lasagna  Don’t hate yourself, but don’t love yourself t...
#
# [75 rows x 3 columns]

# %%
with open("top_tracks.csv", "r") as file:
    print(file.read())
# Out:
# ,Año,Artista,Track
# 0,2020,Will Ferrell,Husavik (My Hometown)
# 1,2020,Will Ferrell,Jaja Ding Dong
# 2,2020,Will Ferrell,Double Trouble - Film Version
# 3,2020,Little Big,Skibidi
# 4,2020,Little Big,Uno
# 5,2020,Little Big,Big Dick
# 6,2020,Diodato,Fai rumore
# 7,2020,Diodato,Ti muovi
# 8,2020,Diodato,Che vita meravigliosa
# 9,2020,BEN & TAN,180 Degree
# 10,2020,BEN & TAN,내 목소리 들리니
# 11,2020,BEN & TAN,Just Like a Dream
# 12,2020,The Mamas,California Dreamin'
# 13,2020,The Mamas,California Dreamin' - Single Version
# 14,2020,The Mamas,Dream A Little Dream Of Me
# 15,2021,Barbara Pravi,Voilà
# 16,2021,Barbara Pravi,Louis
# 17,2021,Barbara Pravi,Prière aux rêves
# 18,2021,Mäneskin,Beggin'
# 19,2021,Mäneskin,I WANNA BE YOUR SLAVE
# 20,2021,Mäneskin,Chosen
# 21,2021,Efendi,Mata Hari
# 22,2021,Efendi,Cleopatra
# 23,2021,Efendi,Mata Hari - slow version
# 24,2021,Tusse,Voices
# 25,2021,Tusse,"I Wanna Be Someone Who's Loved - from the Netflix Series ""Young Royals"""
# 26,2021,Tusse,Rain
# ...

# %%
df.lista_tracks().to_csv("../files/2019/eurovision19_data.csv")
df.lista_tracks().to_json("../files/2019/eurovision19_data.json")

# %%
import requests
import pandas as pd

MY_API_KEY = "d32caae8580221bc7c36700494b0b248"

# Diccionario con los top 5 artistas por año
top_artistas_por_año = {
    2020: ["Will Ferrell", "Little Big", "Diodato", "BEN & TAN", "The Mamas"],
    2021: ["Barbara Pravi", "Mäneskin", "Efendi", "Tusse", "THE ROOP"],
    2022: ["Mahmood", "LUM!X", "S10", "MARO", "Subwoolfer"],
    2023: ["Loreen", "Alessandra", "Käärijä", "Marco Mengoni", "BLANKA"],
    2024: ["Joost", "Nemo", "Slimane", "Angelina Mango", "Baby Lasagna"],
}

def obtener_datos_top_tracks(artista, anio):
    """Obtiene los 3 top tracks de un artista desde Lastfm."""
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={artista}&api_key={MY_API_KEY}&format=json"
    response = requests.get(url)

    if response.status_code == 200:
        datos = response.json()
        
        if "toptracks" in datos and "track" in datos["toptracks"]:
            return [{"Año": año, "Artista": artista, "Track": track["name"]} for track in datos["toptracks"]["track"][:3]]
    return []

# Recorrer los años y artistas para guardar archivos separados
for anio, artistas in top_artistas_por_año.items():
    lista_tracks = []  # Lista para almacenar los datos de cada año
    
    for artista in artistas:
        lista_tracks.extend(obtener_datos_top_tracks(artista, anio))
    
    # Convertir la lista en un DataFrame
    df = pd.DataFrame(lista_tracks)
    
    # Guardar cada año en un archivo CSV separado
    nombre_archivo = f"top_tracks_{año}.csv"
    df.to_csv(nombre_archivo, index=False)
    
    print(f"📁 Archivo guardado: {nombre_archivo}")
# Out:
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv

# %%
import requests
import pandas as pd

MY_API_KEY = "d32caae8580221bc7c36700494b0b248"

# Diccionario con los top 5 artistas por año
top_artistas_por_año = {
    2020: ["Will Ferrell", "Little Big", "Diodato", "BEN & TAN", "The Mamas"],
    2021: ["Barbara Pravi", "Mäneskin", "Efendi", "Tusse", "THE ROOP"],
    2022: ["Mahmood", "LUM!X", "S10", "MARO", "Subwoolfer"],
    2023: ["Loreen", "Alessandra", "Käärijä", "Marco Mengoni", "BLANKA"],
    2024: ["Joost", "Nemo", "Slimane", "Angelina Mango", "Baby Lasagna"],
}

def obtener_datos_top_tracks(artista, anio):
    #Obtiene los 3 top tracks de un artista desde Lastfm api
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={artista}&api_key={MY_API_KEY}&format=json"
    response = requests.get(url)

    if response.status_code == 200:
        datos = response.json()
        
        if "toptracks" in datos and "track" in datos["toptracks"]:
            return [{"Año": año, "Artista": artista, "Track": track["name"]} for track in datos["toptracks"]["track"][:3]]
    return []

# Recorrer los años y artistas para guardar archivos separados
for anio, artistas in top_artistas_por_año.items():
    lista_tracks = []  # Lista para almacenar los datos de cada año
    
    for artista in artistas:
        lista_tracks.extend(obtener_datos_top_tracks(artista, año))
    
    # Convertir la lista en un DataFrame
    df = pd.DataFrame(lista_tracks)
    
    # Guardar cada año en un archivo CSV separado
    nombre_archivo = f"top_tracks_{año}.csv"
    df.to_csv(nombre_archivo, index=False)
    
    print(f"📁 Archivo guardado: {nombre_archivo}")
# Out:
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv

# %%
import requests
import pandas as pd

MY_API_KEY = "d32caae8580221bc7c36700494b0b248"

# Diccionario con los top 5 artistas por año
top_artistas_por_año = {
    2020: ["Will Ferrell", "Little Big", "Diodato", "BEN & TAN", "The Mamas"],
    2021: ["Barbara Pravi", "Mäneskin", "Efendi", "Tusse", "THE ROOP"],
    2022: ["Mahmood", "LUM!X", "S10", "MARO", "Subwoolfer"],
    2023: ["Loreen", "Alessandra", "Käärijä", "Marco Mengoni", "BLANKA"],
    2024: ["Joost", "Nemo", "Slimane", "Angelina Mango", "Baby Lasagna"],
}

def obtener_datos_top_tracks(artista, año):
    #Obtiene los 3 top tracks de un artista desde Lastfm API
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={artista}&api_key={MY_API_KEY}&format=json"
    response = requests.get(url)

    if response.status_code == 200:
        datos = response.json()
        
        if "toptracks" in datos and "track" in datos["toptracks"]:
            return [{"Artista": artista,"Año": año, "Track": track["name"]} for track in datos["toptracks"]["track"][:3]]
    return []

# Recorrer los años y artistas para guardar archivos separados
for anio, artistas in top_artistas_por_año.items():
    lista_tracks = []  # Lista para almacenar los datos de cada año
    
    for artista in artistas:
        lista_tracks.extend(obtener_datos_top_tracks(artista, año))
    
    # Convertir la lista en un DataFrame
    df = pd.DataFrame(lista_tracks)
    
    # Guardar cada año en un archivo CSV separado y se agrega index=False para eliminar el indice 
    nombre_archivo = f"top_tracks_{año}.csv"
    df.to_csv(nombre_archivo, index=False)
    
    print(f"📁 Archivo guardado: {nombre_archivo}")
# Out:
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv
# 📁 Archivo guardado: top_tracks_2024.csv

# %%
import requests
import pandas as pd

MY_API_KEY = "d32caae8580221bc7c36700494b0b248"

# Diccionario con los top 5 artistas por año
top_artistas_por_año = {
    2020: ["Will Ferrell", "Little Big", "Diodato", "BEN & TAN", "The Mamas"],
    2021: ["Barbara Pravi", "Mäneskin", "Efendi", "Tusse", "THE ROOP"],
    2022: ["Mahmood", "LUM!X", "S10", "MARO", "Subwoolfer"],
    2023: ["Loreen", "Alessandra", "Käärijä", "Marco Mengoni", "BLANKA"],
    2024: ["Joost", "Nemo", "Slimane", "Angelina Mango", "Baby Lasagna"],
}

def obtener_datos_top_tracks(artista, año):
    """Obtiene los 3 top tracks de un artista desde Lastfm API."""
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={artista}&api_key={MY_API_KEY}&format=json"
    response = requests.get(url)

    if response.status_code == 200:
        datos = response.json()
        
        if "toptracks" in datos and "track" in datos["toptracks"]:
            return [{"Artista": artista, "Año": año, "Track": track["name"]} for track in datos["toptracks"]["track"][:3]]
    return []

# Lista para almacenar los datos de todos los años
datos_totales = []

# Recorrer los años y artistas para obtener los datos
for anio, artistas in top_artistas_por_año.items():
    for artista in artistas:
        datos_totales.extend(obtener_datos_top_tracks(artista, anio))

# Convertir la lista en un DataFrame
df_total = pd.DataFrame(datos_totales)

# Guardar en un solo archivo CSV
archivo_final = "top_tracks_2020_2024.csv"
df_total.to_csv(archivo_final, index=False)

print(f"📁 Archivo guardado: {archivo_final}")
# Out:
# 📁 Archivo guardado: top_tracks_2020_2024.csv

# %%
import requests
import pandas as pd

MY_API_KEY = "d32caae8580221bc7c36700494b0b248"

# Dictionary with the top 5 artists per year
top_artists_by_year = {
    2020: ["Will Ferrell", "Little Big", "Diodato", "BEN & TAN", "The Mamas"],
    2021: ["Barbara Pravi", "Mäneskin", "Efendi", "Tusse", "THE ROOP"],
    2022: ["Mahmood", "LUM!X", "S10", "MARO", "Subwoolfer"],
    2023: ["Loreen", "Alessandra", "Käärijä", "Marco Mengoni", "BLANKA"],
    2024: ["Joost", "Nemo", "Slimane", "Angelina Mango", "Baby Lasagna"],
}

def get_top_tracks(artist, year):
    """Fetches the top 3 tracks of an artist from the Last.fm API."""
    url = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={artist}&api_key={MY_API_KEY}&format=json"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        
        if "toptracks" in data and "track" in data["toptracks"]:
            return [{"Artist": artist, "Year": year, "Track": track["name"]} for track in data["toptracks"]["track"][:3]]
    return []

# List to store data from all years
all_data = []

# Loop through years and artists to fetch data
for year, artists in top_artists_by_year.items():
    for artist in artists:
        all_data.extend(get_top_tracks(artist, year))

# Convert the list into a DataFrame
df_total = pd.DataFrame(all_data)

# Save to a single CSV file
final_file = "top_tracks_2020_2024.csv"
df_total.to_csv(final_file, index=False)

print(f"📁 File saved: {final_file}")
# Out:
# 📁 File saved: top_tracks_2020_2024.csv

# %%
datos_top_albums = top_albums.json()

# %%
datos_top_albums
# Out:
# {'topalbums': {'album': [{'name': 'Believe',
#     'playcount': 6597431,
#     'mbid': '63b3a8ca-26f2-4e2b-b867-647a6ec2bebd',
#     'url': 'https://www.last.fm/music/Cher/Believe',
#     'artist': {'name': 'Cher',
#      'mbid': 'bfcc6d75-a6a5-4bc6-8282-47aec8531818',
#      'url': 'https://www.last.fm/music/Cher'},
#     'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/3b54885952161aaea4ce2965b2db1638.png',
#       'size': 'small'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/3b54885952161aaea4ce2965b2db1638.png',
#       'size': 'medium'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/3b54885952161aaea4ce2965b2db1638.png',
#       'size': 'large'},
#      {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/3b54885952161aaea4ce2965b2db1638.png',
#       'size': 'extralarge'}]},
#    {'name': 'The Very Best of Cher',
#     'playcount': 1763164,
#     'mbid': 'a7e2dad7-e733-4bee-9db1-b31e3183eaf5',
# ...

# %%
#API tags (géneros) de artistas

tags_artistas = requests.get("http://ws.audioscrobbler.com/2.0/?method=artist.getTags&artist=Red%20Hot%20Chili%20Peppers&user=RJ&api_key=d32caae8580221bc7c36700494b0b248&format=json")

# %%
datos_tags = tags_artistas.json()

# %%
datos_tags
# Out:
# {'tags': {'tag': [{'name': 'rock', 'url': 'https://www.last.fm/tag/rock'},
#    {'name': 'funky', 'url': 'https://www.last.fm/tag/funky'}],
#   '@attr': {'artist': 'Red Hot Chili Peppers'}}}

# %% [markdown]
# 25 de Feb
#  - que dato es el que realmente vamos a sacar?
#  - limpiar datos
#  - armar data frame
